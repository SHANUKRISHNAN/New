# %%
Next=input("What to do ")
Then_What=input('What next')
if Next=='job':
    print("Good luck") 
else:
    print("Find")
if Then_What=="Nothing":
    print('Moonjj')
# Out:
# What to do  job

# %%
import  pandas as pd
import numpy as np
