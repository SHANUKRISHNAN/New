# %%
 records = [{"name": "ana",  "score": 88, "tags": ["nlp", "vision"]},{"name": "ben",  "score": 92, "tags": ["vision"]},{"name": "cleo", "score": 79, "tags": ["nlp"]},{"name": "dev",  "score": 95, "tags": ["rl"]},{"name": "eve",  "score": 84, "tags": ["nlp", "rl"]},]

# %%
# Out:
# [{'name': 'ana', 'score': 88, 'tags': ['nlp', 'vision']},
#  {'name': 'ben', 'score': 92, 'tags': ['vision']},
#  {'name': 'cleo', 'score': 79, 'tags': ['nlp']},
#  {'name': 'dev', 'score': 95, 'tags': ['rl']},
#  {'name': 'eve', 'score': 84, 'tags': ['nlp', 'rl']}]

# %%
# Out:
# {'name': 'dev', 'score': 95, 'tags': ['rl']}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 records['name']
#
# TypeError: list indices must be integers or slices, not str
